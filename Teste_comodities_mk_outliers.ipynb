# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import gc
from scipy.sparse import eye, hstack, vstack, csr_matrix, identity
import statsmodels.api as sm
import math
import gurobipy as gp
from gurobipy import GRB
import seaborn as sns
from matplotlib import colors as mcolors
np.set_printoptions(precision=9, floatmode='fixed', suppress=True)
from matplotlib.ticker import FuncFormatter

# %%
# Input data ------------------------------------------------------------------------------------------------
start='2019-01-01'                  # Start data
end= '2022-01-01'                   # End data

index = 1                           # American_market_SP500_'^GSPC' --> 1 or Brazilian_Market_Ibovespa_'^BVSP' --> 2
T = 252                         # number of training days
#R =252*2                         # number of days for the rebalancing period
psi_list = [0.2, 0.5, 0.8]          # regularization psi values
matriz_Q = 1                        # cov^-0.5 --> 1, eye --> 2, Whitening --> 3
gamma = 1                           # Risk aversion coef
cut = 1e-6                          # Precision alphas
regularization = 1e-3               # Regularization matrix
alpha_var = 0                   # Confidence level: VaR and CVaR
confidence_level = int(alpha_var*100)    # Confidence level (%)

risk_free_rate = 0
threshold = 0.10
#  -------------------------------------------------------------------------------------------------------
colors_svc = ['#9ca09a', '#6a7168', '#30302f']
def get_colors(num_methods):
    if num_methods <= 3:
        return colors_svc[:num_methods]
    else:
        additional_colors = plt.cm.viridis(np.linspace(0, 1, num_methods - 3))
        return colors_svc + [mcolors.rgb2hex(c) for c in additional_colors]

num_methods = len(psi_list)
colors_svc = get_colors(num_methods)

cores_personalizadas = ['lightblue', 'salmon', '#9ca09a', '#6a7168', '#30302f']
cores = {0.2: '#9ca09a', 0.5: '#6a7168', 0.8: '#30302f'}
cor_0_2 = list(cores.keys())[0]
cor1 = cores[cor_0_2]
cor_0_5 = list(cores.keys())[1]
cor2 = cores[cor_0_5]
cor_0_8 = list(cores.keys())[2]
cor3 = cores[cor_0_8]

# %%
#### --------------------------------------------------------------------------
## Comodities
# # Benchmark único (padrão de comparação)
# possible_benchmarks = ['SPY', 'AGG', 'GLD']
symbol_index = '^BCOM'#'^BVSP' #'SPY' # ['SPY', 'AGG', 'GLD']'^BCOM' 
hist_index = yf.download(symbol_index, start=start, end=end)['Close']
retornos_indices = hist_index.pct_change()

tickers = [
    'ZS=F',  # Soja
    'ZC=F',  # Milho
    'KC=F',  # Café
    'SB=F',  # Açúcar
    'CT=F',  # Algodão
    'ZW=F',  # Trigo
    'LE=F',  # Boi gordo
    'HE=F',  # Porco
    'TIO=F', # Minério de ferro
    'CL=F',  # Petróleo WTI
    'BZ=F',  # Brent
    'ALI=F', # Alumínio
    'GC=F'   # Ouro
]

                   
data = yf.download(tickers, start, end)['Close']
data_clean = data.dropna(axis=1)
data_clean = data_clean.dropna()
retornos_ativos = data_clean.pct_change().dropna()
# ------------------------------------------------------------------------------------------------ 

retornos_indices = retornos_indices.tz_localize(None)
dados_completos = retornos_ativos.join(retornos_indices)
df = pd.DataFrame(dados_completos)

df_assets = df.iloc[:, :-1]  # dados completos 
df_bench = df.iloc[:,-1]
num_returns_total, num_assets_total = df_assets.shape
# Out:
# /var/folders/87/ynv0vm3x3w3_xj6zkm4nkw_40000gn/T/ipykernel_41629/784675367.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   hist_index = yf.download(symbol_index, start=start, end=end)['Close']
# [*********************100%***********************]  1 of 1 completed
# /var/folders/87/ynv0vm3x3w3_xj6zkm4nkw_40000gn/T/ipykernel_41629/784675367.py:26: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start, end)['Close']
# [*********************100%***********************]  13 of 13 completed

# %%
print(df_assets.head())
# Out:
# Ticker      ALI=F      BZ=F      CL=F      CT=F      GC=F      HE=F      KC=F  \
# Date
# 2019-01-03    0.0  0.018940  0.011818 -0.000141  0.008431  0.007293  0.026633
# 2019-01-04    0.0  0.019839  0.018475  0.023860 -0.007045 -0.003218 -0.005384
# 2019-01-07    0.0  0.004732  0.011676  0.003172  0.003196 -0.000807  0.011319
# 2019-01-08    0.0  0.024246  0.025969 -0.014845 -0.002798  0.011309  0.022384
# 2019-01-09    0.0  0.046321  0.051828  0.020371  0.004754  0.018770  0.002380
#
# Ticker          LE=F      SB=F     TIO=F      ZC=F      ZS=F      ZW=F
# Date
# 2019-01-03 -0.002429 -0.020117  0.016465  0.010645  0.006147  0.013814
# 2019-01-04 -0.010550  0.020530  0.011906  0.008558  0.010275  0.006326
# 2019-01-07  0.010457  0.060352  0.014503 -0.001958  0.003024 -0.000484
# 2019-01-08  0.017046  0.008696  0.000809 -0.005886 -0.006577  0.001935
# 2019-01-09 -0.003990  0.008621 -0.002021  0.005263  0.005793  0.004346

# %%
print(df_bench.head())
# Out:
# Date
# 2019-01-03    0.005975
# 2019-01-04    0.011491
# 2019-01-07    0.002936
# 2019-01-08    0.004836
# 2019-01-09    0.012160
# Name: ^BCOM, dtype: float64

# %% [markdown]
# <!-- -->

# %%
# SOLVER: GUROBI -------------------------------------------------------------
def calculate_mk_optimum_weights(returns, gamma):
    returns_np = np.array(returns)
    num_returns, num_assets = returns.shape
    mu = np.mean(returns_np, axis=0)
    cov_matrix = np.cov(returns_np, rowvar=False)
    P = gamma*cov_matrix
    q = mu
    model = gp.Model()
    w = model.addMVar(shape=num_assets, lb=0, ub=1, name="w")
    objective = -w @ P @ w + q.T @ w
    model.setObjective(objective, GRB.MAXIMIZE)
    model.addConstr(w.sum() == 1, "c0")
    model.optimize()
    if model.status == GRB.OPTIMAL:
        print("Status MK: Optimal")
        return w.x
    else:
        print(f"Status MK: {model.status}")
        return None

# %%
## Gram matrix (WGI) -----------------------------------------------------------
def calculate_wgi_kernel(num_returns, df_assets_np, Q):
    lk_const = 1.3
    product_Q_return = np.dot(Q.T, df_assets_np.T)
    l = lk_const * (np.max(product_Q_return, axis=1) - np.min(product_Q_return, axis=1))
    l_sum = np.sum(l)
    K = np.zeros((num_returns, num_returns))
    for i in range(num_returns):
        diff_return = df_assets_np - df_assets_np[i, :]
        K[i, :] = l_sum - np.linalg.norm(np.dot(Q, diff_return.T), ord=1, axis=0)
    return K

## Precision alphas: SVS, BSVS, IDS -------------------------------------------------
def adjust_alpha_values(x_values, limit_alpha, cut):
    for i in range(len(x_values)):
        if x_values[i] <= cut:
            x_values[i] = 0
        elif np.abs(x_values[i] - limit_alpha) < cut:
            x_values[i] = limit_alpha
    return x_values

## -----------------------------------------------------------------------------------
# OPTIMIZATION SVC
## -----------------------------------------------------------------------------------
def calculate_svc_optimum_weights(returns, gamma, psi):
    num_returns, num_assets= returns.shape
    returns_np = np.array(returns)
    cov_matrix = np.cov(returns, rowvar=False)

    # Matriz Q ------------------------------------------------------------------------
    if matriz_Q == 1:
        cov_matrix = np.cov(returns_np, rowvar=False)
        U, S, Vt = np.linalg.svd(cov_matrix)
        Q = np.dot(U, np.diag(1.0 / np.sqrt(S))).dot(Vt)
    elif matriz_Q == 2:
        Q = np.eye(num_assets)
    elif matriz_Q==3:
        returns_np_centered = returns_np - np.mean(returns_np, axis=0)
        cov_matrix_centered = np.cov(returns_np_centered, rowvar=False)
        U, S, Vt = np.linalg.svd(cov_matrix_centered)
        Q = np.dot(U, np.diag(1.0 / np.sqrt(S + cut))).dot(U.T)
    else:
        print("Error: Q matrix")
        exit()


    # Matriz K -----------------------------------------------------------------------
    K = calculate_wgi_kernel(num_returns, returns_np, Q)


    # GUROBI OPTIMIZATION: uncertatin set---------------------------------------------
    limite_alpha=1/(num_returns*psi)
    P=K
    q=np.diagonal(K)
    model = gp.Model()
    x = model.addMVar(shape=num_returns, lb=0, ub=limite_alpha, name="Uncertainty")
    objective =  -x @ P @ x + q @ x
    model.setObjective(objective, GRB.MAXIMIZE)
    model.addConstr(x.sum() == 1)
    model.optimize()
    if model.status == GRB.OPTIMAL:
        solution = x.X
        print("Optimal solution - SVC (WGI) part 1:", solution)
    else:
        print("No optimal solution found - SVC (WGI) part 1")
    x_values=solution


    # Rounding of alphas ---------------------------------------------------------------
    x_adjust = adjust_alpha_values(x_values, limite_alpha, cut)
    svs = np.where(x_adjust > 0)[0]
    bsvs = np.where((x_adjust > 0) & (x_adjust < limite_alpha))[0]
    n_svs = svs.size
    n_bsvs = bsvs.size
    returns_np_bsvs = returns_np[bsvs]
    returns_np_svs = returns_np[svs]


    # Theta parameter -------------------------------------------------------------------
    thetas = np.zeros(n_bsvs)
    for j in range(n_bsvs):
        theta = 0
        for i in range(n_svs):
            theta += x_adjust[i] * np.linalg.norm(Q @ (returns_np_bsvs[j, :] - returns_np_svs[i, :]), ord=1)
        thetas[j] = theta
    theta_min_ = np.min(thetas)
    theta_min=theta_min_*np.ones(1)


    # GUROBI OPTIMIZATION: weights -------------------------------------------------------
    n_var = 2*n_svs*num_assets+num_assets+1


    # Quadratical term-------------------------------------------------------------------
    cov_complet = csr_matrix((num_assets, n_var - num_assets))
    sparse_top = hstack([csr_matrix(cov_matrix), cov_complet])
    sparse_bottom = csr_matrix((n_var - num_assets, n_var))
    P = gamma * vstack([sparse_top, sparse_bottom]).tocsc()


    # Linear term-------------------------------------------------------------------------
    aux_q1=csr_matrix(np.zeros((num_assets, 1)))
    result_list = []
    for i in range(n_svs):
        result = np.dot(returns_np_svs[i, :], Q)
        result_list.append(result.flatten())
    auxiliary = np.concatenate(result_list)
    auxiliary=np.array([auxiliary]).reshape(-1, 1)
    arr = np.array([theta_min])
    theta_min = arr.reshape(1, 1)
    q=vstack([aux_q1, theta_min, -auxiliary, +auxiliary], dtype=np.float32)


    # Equality constraints --------------------------------------------------------------
    repet_Q=np.kron(np.ones((1, n_svs)), Q)
    A2 = np.hstack((np.eye(num_assets), np.zeros((num_assets, 1)), -np.array(repet_Q), np.array(repet_Q)))
    b2 = np.zeros(num_assets)
    alphas_svs = x_adjust[svs]
    repeated_alphas = np.repeat(alphas_svs, num_assets)
    A3_2 = csr_matrix(repeated_alphas).T
    A3_3 = eye(num_assets*n_svs, format='csr')
    b3 = np.zeros(num_assets*n_svs)
    part_1 = csr_matrix((num_assets*n_svs, num_assets))
    A3 = hstack([part_1, A3_2, -A3_3, -A3_3])
    A = vstack([A2, A3], dtype=np.float32).toarray()
    b = np.concatenate([b2, b3], dtype=np.float32)


    # Model call ------------------------------------------------------------------------
    P_regularized = P + regularization*identity(n_var, format = 'coo')
    model2 = gp.Model()
    x2 = model2.addMVar(shape=n_var, lb=0, name="Portfolio")
    x2[:num_assets].ub = 1
    objective = -x2 @ P_regularized @ x2 - q.T @ x2
    model2.setObjective(objective, GRB.MAXIMIZE)
    model2.addConstr(x2[:num_assets].sum() == 1)
    model2.addConstr(A @ x2 == b)
    model2.optimize()

    if model2.status == GRB.OPTIMAL:
        solution2 = x2.X
        print("Optimal solution - SVC (WGI) part 2:", solution2)
    else:
        print("No optimal solution found - SVC (WGI) part 2")
    return solution2[:num_assets]

# %%
def calculate_drawdown(cumulative_returns):
    cumulative_returns = np.array(cumulative_returns)
    peaks = np.maximum.accumulate(cumulative_returns)
    drawdowns = (cumulative_returns - peaks) / peaks
    max_drawdown = drawdowns.min()
    return max_drawdown


def calculate_var(portfolio_returns, confidence_level=0.95):
    portfolio_returns = np.array(portfolio_returns)
    var = np.percentile(portfolio_returns, (1 - confidence_level) * 100)
    return var


def calculate_cvar(portfolio_returns, confidence_level=0.95):
    portfolio_returns = np.array(portfolio_returns)
    var = calculate_var(portfolio_returns, confidence_level)
    cvar = portfolio_returns[portfolio_returns <= var].mean()
    return cvar


def calculate_alpha_beta(portfolio_returns, market_index):
    portfolio_returns = np.array(portfolio_returns)
    market_returns = np.array(market_index)
    mask = np.isfinite(portfolio_returns) & np.isfinite(market_returns)
    portfolio_returns = portfolio_returns[mask]
    market_returns = market_returns[mask]
    if len(portfolio_returns) < 2:
        raise ValueError("Insufficient data after removing non-finite values.")
    X = sm.add_constant(market_returns)
    try:
        model = sm.OLS(portfolio_returns, X).fit()
    except Exception as e:
        raise ValueError(f"Error fitting the model: {str(e)}")
    if model.params.shape[0] < 2:
        raise ValueError("The regression model did not return enough parameters.")
    alpha = model.params[0]
    beta = model.params[1]
    return alpha, beta


def calculate_sharpe_ratio(portfolio_returns, risk_free_rate):
    portfolio_returns = np.array(portfolio_returns)
    excess_returns = portfolio_returns - risk_free_rate
    sharpe_ratio = np.mean(excess_returns) / np.std(excess_returns)
    return sharpe_ratio


def calculate_sortino_ratio(portfolio_returns, risk_free_rate):
    portfolio_returns = np.array(portfolio_returns)
    negative_returns = portfolio_returns[portfolio_returns < risk_free_rate]
    downside_deviation = np.std(negative_returns)
    excess_returns = portfolio_returns - risk_free_rate
    sortino_ratio = np.mean(excess_returns) / downside_deviation
    return sortino_ratio


def calculate_omega_ratio(portfolio_returns, target_return):
    portfolio_returns = np.array(portfolio_returns)
    gains = portfolio_returns[portfolio_returns > target_return] - target_return
    losses = target_return - portfolio_returns[portfolio_returns < target_return]
    omega_ratio = np.sum(gains) / np.sum(losses)
    return omega_ratio

# %%
gc.collect()

R = 63

test = df_assets.iloc[T:]
training = df_assets[:T]

window_size = T
rebalancing_interval = R
num_rebal = math.ceil((num_returns_total - window_size)/rebalancing_interval)

cumulative_portfolio_returns_svc_dict = {psi: [] for psi in psi_list}
cumulative_portfolio_returns_mk_dict_filtro = {psi: [] for psi in psi_list}
cumulative_portfolio_returns_equal=[]
cumulative_portfolio_returns_mk=[]
dates = []


diversity_svc_dict = {psi: [] for psi in psi_list}
diversity_mk_dict_filtro = {psi: [] for psi in psi_list}
diversity_mk = []


hhi_svc_dict = {psi: [] for psi in psi_list}
hhi_mk_dict_filtro = {psi: [] for psi in psi_list}
hhi_mk_list = []
hhi_equal_list = []


weights_svc_dict = {psi: [] for psi in psi_list}
weights_mk_dict_filtro = {psi: [] for psi in psi_list}
weights_mk_list = []
weights_equal_list = []


turnover_svc_dict = {psi: [] for psi in psi_list}
turnover_mk_dict_filtro = {psi: [] for psi in psi_list}
turnover_mk = []
turnover_equal = []


previous_weights_svc = {psi: None for psi in psi_list}
previous_weights_mk_filtro = {psi: None for psi in psi_list}
previous_weights_mk = None
previous_weights_equal = None

print("Number of rebalancings/optimizations: ", num_rebal)

for i, start in enumerate(range(0, num_returns_total- window_size, rebalancing_interval)):
    end = start + window_size
    window_data = df_assets.iloc[start:end]
    num_periodos, num_assets = window_data.shape

    weights_svc={}
    for psi in psi_list:
        weights_svc[psi] = calculate_svc_optimum_weights(window_data, gamma, psi)
    weights_mk_filtro={}
    for psi in psi_list:
        mean_vector = window_data.mean()
        distances = ((window_data - mean_vector) ** 2).sum(axis=1) ** 0.5
        filtro = distances.quantile(psi)  # escalar
        window_data_filtro = window_data[distances <= filtro]
        weights_mk_filtro[psi] = calculate_mk_optimum_weights(window_data_filtro, gamma)

    weights_mk = calculate_mk_optimum_weights(window_data, gamma)
    weights_equal = np.repeat(1/num_assets, num_assets)


    if previous_weights_mk is not None:
        for psi in psi_list:
            turnover_svc_dict[psi].append(np.sum(np.abs(weights_svc[psi] - previous_weights_svc[psi])))
        for psi in psi_list:
            turnover_mk_dict_filtro[psi].append(np.sum(np.abs(weights_mk_filtro[psi] - previous_weights_mk_filtro[psi])))

            turnover_mk.append(np.sum(np.abs(weights_mk - previous_weights_mk)))
            turnover_equal.append(np.sum(np.abs(weights_equal - previous_weights_equal)))


    previous_weights_svc ={}
    for psi in psi_list:
        previous_weights_svc[psi] = weights_svc[psi]
    previous_weights_mk_filtro ={}
    for psi in psi_list:
        previous_weights_mk_filtro[psi] = weights_mk_filtro[psi]

    previous_weights_mk = weights_mk
    previous_weights_equal = weights_equal

    hhi_svc={}
    for psi in psi_list:
        hhi_svc[psi] = np.sum(weights_svc[psi]**2)
    hhi_mk_filtro={}
    for psi in psi_list:
        hhi_mk_filtro[psi] = np.sum(weights_mk_filtro[psi]**2)
    hhi_mk = np.sum(weights_mk**2)
    hhi_equal = np.sum(weights_equal**2)

    num_assets_svc_rebal ={}
    for psi in psi_list:
        num_assets_svc_rebal[psi] = np.count_nonzero(weights_svc[psi]>cut)
    num_assets_mk_rebal_filtro ={}
    for psi in psi_list:
        num_assets_mk_rebal_filtro[psi] = np.count_nonzero(weights_mk_filtro[psi]>cut)


    num_assets_mk_rebal = np.count_nonzero(weights_mk>cut)

    print(f"End of optimization {i+1} ----")

    next_period = df_assets.iloc[end:end + rebalancing_interval]
    if not next_period.empty:
        for psi in psi_list:
            weights_svc[psi] = calculate_svc_optimum_weights(window_data, gamma, psi)
            portfolio_returns_svc = next_period.dot(weights_svc[psi])
            cumulative_portfolio_returns_svc_dict[psi].extend(portfolio_returns_svc)
            diversity_svc_dict[psi].append(num_assets_svc_rebal[psi])
            hhi_svc_dict[psi].append(hhi_svc[psi])
            weights_svc_dict[psi].append(weights_svc[psi])

        for psi in psi_list:
            weights_mk_filtro[psi] = calculate_svc_optimum_weights(window_data_filtro, gamma, psi)
            portfolio_returns_mk_filtro= next_period.dot(weights_mk_filtro[psi])
            cumulative_portfolio_returns_mk_dict_filtro[psi].extend(portfolio_returns_mk_filtro)
            diversity_mk_dict_filtro[psi].append(num_assets_mk_rebal_filtro[psi])
            hhi_mk_dict_filtro[psi].append(hhi_mk_filtro[psi])
            weights_mk_dict_filtro[psi].append(weights_mk_filtro[psi])

        portfolio_returns_mk = next_period.dot(weights_mk)
        cumulative_portfolio_returns_mk.extend(portfolio_returns_mk)
        diversity_mk.append(num_assets_mk_rebal)
        hhi_mk_list.append(hhi_mk)
        weights_mk_list.append(weights_mk)

        portfolio_returns_equal = next_period.dot(weights_equal)
        cumulative_portfolio_returns_equal.extend(portfolio_returns_equal)
        hhi_equal_list.append(hhi_equal)
        weights_equal_list.append(weights_equal)

        dates.extend(next_period.index)


diversity_equal = np.repeat(num_assets, num_rebal)

cumulative_portfolio_returns_svc_series = {psi: [] for psi in psi_list}
cumulative_returns_svc = {psi: [] for psi in psi_list}
for psi in psi_list:
    cumulative_portfolio_returns_svc_series[psi] = pd.Series(cumulative_portfolio_returns_svc_dict[psi], index=dates)
    cumulative_returns_svc[psi] = (1 + cumulative_portfolio_returns_svc_series[psi]).cumprod() - 1



cumulative_portfolio_returns_mk_series_filtro = {psi: [] for psi in psi_list}
cumulative_returns_mk_filtro= {psi: [] for psi in psi_list}
for psi in psi_list:
    cumulative_portfolio_returns_mk_series_filtro[psi] = pd.Series(cumulative_portfolio_returns_mk_dict_filtro[psi], index=dates)
    cumulative_returns_mk_filtro[psi] = (1 + cumulative_portfolio_returns_mk_series_filtro[psi]).cumprod() - 1



cumulative_portfolio_returns_equal_series = pd.Series(cumulative_portfolio_returns_equal, index=dates)
cumulative_return_equal = (1 + cumulative_portfolio_returns_equal_series).cumprod() - 1

cumulative_portfolio_returns_mk_series = pd.Series(cumulative_portfolio_returns_mk, index=dates)
cumulative_return_mk = (1 + cumulative_portfolio_returns_mk_series).cumprod() - 1

cumulative_return_bench= (1 + df_bench.iloc[window_size:]).cumprod() - 1


######################

# Volatilidade
volatility_svc_1 = np.std(cumulative_portfolio_returns_svc_series[0.2]) 
volatility_svc_2 = np.std(cumulative_portfolio_returns_svc_series[0.5]) 
volatility_svc_3 = np.std(cumulative_portfolio_returns_svc_series[0.8]) 
volatility_mk = np.std(cumulative_portfolio_returns_mk_series)
volatility_equal = np.std(cumulative_portfolio_returns_equal_series)
volatility_bench = np.std(cumulative_return_bench)
volatility_mk_1 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.2]) 
volatility_mk_2 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.5]) 
volatility_mk_3 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.8]) 


# Drawdown
drawdown_svc_1 = calculate_drawdown(cumulative_returns_svc[0.2])
drawdown_svc_2 = calculate_drawdown(cumulative_returns_svc[0.5])
drawdown_svc_3 = calculate_drawdown(cumulative_returns_svc[0.8])
drawdown_mk = calculate_drawdown(cumulative_return_mk)
drawdown_equal = calculate_drawdown(cumulative_return_equal)
drawdown_bench = calculate_drawdown(cumulative_return_bench)
drawdown_mk_1 = calculate_drawdown(cumulative_returns_mk_filtro[0.2])
drawdown_mk_2 = calculate_drawdown(cumulative_returns_mk_filtro[0.5])
drawdown_mk_3 = calculate_drawdown(cumulative_returns_mk_filtro[0.8])


# # VaR
var_svc_1 = calculate_var(cumulative_portfolio_returns_svc_series[0.2], 0.95)
var_svc_2 = calculate_var(cumulative_portfolio_returns_svc_series[0.5], 0.95)
var_svc_3 = calculate_var(cumulative_portfolio_returns_svc_series[0.8], 0.95)
var_mk = calculate_var(cumulative_portfolio_returns_mk_series, 0.95)
var_equal = calculate_var(cumulative_portfolio_returns_equal_series, 0.95)
var_bench = calculate_var(df_bench.iloc[T:], 0.95)
var_mk_1 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.2], 0.95)
var_mk_2 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.5], 0.95)
var_mk_3 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.8], 0.95)

# # CVaR
cvar_svc_1 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.2], 0.95)
cvar_svc_2 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.5], 0.95)
cvar_svc_3 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.8], 0.95)
cvar_mk = calculate_cvar(cumulative_portfolio_returns_mk_series, 0.95)
cvar_equal = calculate_cvar(cumulative_portfolio_returns_equal_series, 0.95)
cvar_bench = calculate_cvar(df_bench.iloc[T:], 0.95)
cvar_mk_1 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.2], 0.95)
cvar_mk_2 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.5], 0.95)
cvar_mk_3 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.8], 0.95)


# # Sharpe
sharpe_ratio_svc_1 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.2], risk_free_rate)
sharpe_ratio_svc_2 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.5], risk_free_rate)
sharpe_ratio_svc_3 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.8], risk_free_rate)
sharpe_ratio_mk = calculate_sharpe_ratio(cumulative_return_mk, risk_free_rate)
sharpe_ratio_equal = calculate_sharpe_ratio(cumulative_return_equal, risk_free_rate)
sharpe_ratio_bench = calculate_sharpe_ratio(df_bench.iloc[T:], risk_free_rate)
sharpe_ratio_mk_1 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], risk_free_rate)
sharpe_ratio_mk_2 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], risk_free_rate)
sharpe_ratio_mk_3 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], risk_free_rate)

# # Sortino
sortino_ratio_svc_1 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.2], risk_free_rate)
sortino_ratio_svc_2 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.5], risk_free_rate)
sortino_ratio_svc_3 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.8], risk_free_rate)
sortino_ratio_mk = calculate_sortino_ratio(cumulative_return_mk, risk_free_rate)
sortino_ratio_equal = calculate_sortino_ratio(cumulative_return_equal, risk_free_rate)
sortino_ratio_bench= calculate_sortino_ratio(df_bench.iloc[T:], risk_free_rate)
sortino_ratio_mk_1 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], risk_free_rate)
sortino_ratio_mk_2 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], risk_free_rate)
sortino_ratio_mk_3 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], risk_free_rate)

# # Omega
omega_ratio_svc_1 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.2], threshold)
omega_ratio_svc_2 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.5], threshold)
omega_ratio_svc_3 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.8], threshold)
omega_ratio_mk = calculate_omega_ratio(cumulative_return_mk,  threshold)
omega_ratio_equal = calculate_omega_ratio(cumulative_return_equal,  threshold)
omega_ratio_bench = calculate_omega_ratio(df_bench.iloc[T:],  threshold)
omega_ratio_mk_1 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], threshold)
omega_ratio_mk_2 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], threshold)
omega_ratio_mk_3 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], threshold)

return_mean_svc_1 = np.mean(cumulative_portfolio_returns_svc_series[0.2])
return_mean_svc_2 = np.mean(cumulative_portfolio_returns_svc_series[0.5])
return_mean_svc_3 = np.mean(cumulative_portfolio_returns_svc_series[0.8])
return_mean_equal = np.mean(cumulative_portfolio_returns_equal_series)
return_mean_mk = np.mean(cumulative_portfolio_returns_mk_series)
return_mean_bench = np.mean(df_bench.iloc[window_size:])
return_mean_mk_1 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.2])
return_mean_mk_2 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.5])
return_mean_mk_3 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.8])

# measures = {
#     "Volatility": [volatility_svc_1, volatility_svc_2, volatility_svc_3, volatility_mk, volatility_equal, volatility_bench, volatility_mk_1, volatility_mk_2, volatility_mk_3],
#     "Max Drawdown": [drawdown_svc_1, drawdown_svc_2, drawdown_svc_3, drawdown_mk, drawdown_equal, drawdown_bench, drawdown_mk_1, drawdown_mk_2, drawdown_mk_3],
#     "VaR (95%)": [var_svc_1, var_svc_2, var_svc_3, var_mk, var_equal, var_bench, var_mk_1, var_mk_2, var_mk_3],
#     "CVaR (95%)": [cvar_svc_1, cvar_svc_2, cvar_svc_3, cvar_mk, cvar_equal, cvar_bench, var_mk_1, cvar_mk_2, cvar_mk_3],
#     "Sharpe": [sharpe_ratio_svc_1, sharpe_ratio_svc_2, sharpe_ratio_svc_3, sharpe_ratio_mk, sharpe_ratio_equal, sharpe_ratio_bench, sharpe_ratio_mk_1, sharpe_ratio_mk_2, sharpe_ratio_mk_3],
#     "Sortino": [sortino_ratio_svc_1, sortino_ratio_svc_2, sortino_ratio_svc_3, sortino_ratio_mk, sortino_ratio_equal, sortino_ratio_bench, sortino_ratio_mk_1, sortino_ratio_mk_2, sortino_ratio_mk_3],
#     "Omega": [omega_ratio_svc_1, omega_ratio_svc_2, omega_ratio_svc_3, omega_ratio_mk, omega_ratio_equal, omega_ratio_bench, omega_ratio_mk_1, omega_ratio_mk_2, omega_ratio_mk_3],
#     "Return mean": [return_mean_svc_1, return_mean_svc_2, return_mean_svc_3, return_mean_mk, return_mean_equal, return_mean_bench, return_mean_mk_1, return_mean_mk_2, return_mean_mk_3]}    
# index = ["SVC_1", "SVC_2", "SVC_3", "Markowitz", "Equal-Weights", "Bench", "MK_1", "MK_2", "MK_3"]
# risk_measures_df_rebalanceado_trimestral = pd.DataFrame(measures, index=index)
# print(risk_measures_df_rebalanceado_trimestral)

measures = {
    "Volatility": [volatility_mk, volatility_mk_1, volatility_mk_2, volatility_mk_3],
    "Max Drawdown": [drawdown_mk, drawdown_mk_1, drawdown_mk_2, drawdown_mk_3],
    "VaR (95%)": [var_mk, var_mk_1, var_mk_2, var_mk_3],
    "CVaR (95%)": [cvar_mk, var_mk_1, cvar_mk_2, cvar_mk_3],
    "Sharpe": [sharpe_ratio_mk, sharpe_ratio_mk_1, sharpe_ratio_mk_2, sharpe_ratio_mk_3],
    "Sortino": [sortino_ratio_mk, sortino_ratio_mk_1, sortino_ratio_mk_2, sortino_ratio_mk_3],
    "Omega": [omega_ratio_mk, omega_ratio_mk_1, omega_ratio_mk_2, omega_ratio_mk_3],
    "Return mean": [return_mean_mk, return_mean_mk_1, return_mean_mk_2, return_mean_mk_3]}    
index = ['MK', 'MK$_{0.2}$', 'MK$_{0.5}$', 'MK$_{0.8}$']
risk_measures_df_rebalanceado_trimestral = pd.DataFrame(measures, index=index)
print(risk_measures_df_rebalanceado_trimestral)
# Out:
# Number of rebalancings/optimizations:  8
# Set parameter LicenseID to value 2530977
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.6.0 24G419)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1 rows, 252 columns and 252 nonzeros
# Model fingerprint: 0x3e01b903
# Model has 31878 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   QObjective range [3e+02, 6e+02]
#   Bounds range     [2e-02, 2e-02]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 1 rows, 252 columns, 252 nonzeros
# Presolved model has 31878 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 251
#  AA' NZ     : 3.163e+04
#  Factor NZ  : 3.188e+04 (roughly 1 MB of memory)
#  Factor Ops : 5.366e+06 (less than 1 second per iteration)
#  Threads    : 8
#
# ...

# %%
gc.collect()

R = 126

test = df_assets.iloc[T:]
training = df_assets[:T]

window_size = T
rebalancing_interval = R
num_rebal = math.ceil((num_returns_total - window_size)/rebalancing_interval)

cumulative_portfolio_returns_svc_dict = {psi: [] for psi in psi_list}
cumulative_portfolio_returns_mk_dict_filtro = {psi: [] for psi in psi_list}
cumulative_portfolio_returns_equal=[]
cumulative_portfolio_returns_mk=[]
dates = []


diversity_svc_dict = {psi: [] for psi in psi_list}
diversity_mk_dict_filtro = {psi: [] for psi in psi_list}
diversity_mk = []


hhi_svc_dict = {psi: [] for psi in psi_list}
hhi_mk_dict_filtro = {psi: [] for psi in psi_list}
hhi_mk_list = []
hhi_equal_list = []


weights_svc_dict = {psi: [] for psi in psi_list}
weights_mk_dict_filtro = {psi: [] for psi in psi_list}
weights_mk_list = []
weights_equal_list = []


turnover_svc_dict = {psi: [] for psi in psi_list}
turnover_mk_dict_filtro = {psi: [] for psi in psi_list}
turnover_mk = []
turnover_equal = []


previous_weights_svc = {psi: None for psi in psi_list}
previous_weights_mk_filtro = {psi: None for psi in psi_list}
previous_weights_mk = None
previous_weights_equal = None

print("Number of rebalancings/optimizations: ", num_rebal)

for i, start in enumerate(range(0, num_returns_total- window_size, rebalancing_interval)):
    end = start + window_size
    window_data = df_assets.iloc[start:end]
    num_periodos, num_assets = window_data.shape

    weights_svc={}
    for psi in psi_list:
        weights_svc[psi] = calculate_svc_optimum_weights(window_data, gamma, psi)
    weights_mk_filtro={}
    for psi in psi_list:
        mean_vector = window_data.mean()
        distances = ((window_data - mean_vector) ** 2).sum(axis=1) ** 0.5
        filtro = distances.quantile(psi)  # escalar
        window_data_filtro = window_data[distances <= filtro]
        weights_mk_filtro[psi] = calculate_mk_optimum_weights(window_data_filtro, gamma)

    weights_mk = calculate_mk_optimum_weights(window_data, gamma)
    weights_equal = np.repeat(1/num_assets, num_assets)


    if previous_weights_mk is not None:
        for psi in psi_list:
            turnover_svc_dict[psi].append(np.sum(np.abs(weights_svc[psi] - previous_weights_svc[psi])))
        for psi in psi_list:
            turnover_mk_dict_filtro[psi].append(np.sum(np.abs(weights_mk_filtro[psi] - previous_weights_mk_filtro[psi])))

            turnover_mk.append(np.sum(np.abs(weights_mk - previous_weights_mk)))
            turnover_equal.append(np.sum(np.abs(weights_equal - previous_weights_equal)))


    previous_weights_svc ={}
    for psi in psi_list:
        previous_weights_svc[psi] = weights_svc[psi]
    previous_weights_mk_filtro ={}
    for psi in psi_list:
        previous_weights_mk_filtro[psi] = weights_mk_filtro[psi]

    previous_weights_mk = weights_mk
    previous_weights_equal = weights_equal

    hhi_svc={}
    for psi in psi_list:
        hhi_svc[psi] = np.sum(weights_svc[psi]**2)
    hhi_mk_filtro={}
    for psi in psi_list:
        hhi_mk_filtro[psi] = np.sum(weights_mk_filtro[psi]**2)
    hhi_mk = np.sum(weights_mk**2)
    hhi_equal = np.sum(weights_equal**2)

    num_assets_svc_rebal ={}
    for psi in psi_list:
        num_assets_svc_rebal[psi] = np.count_nonzero(weights_svc[psi]>cut)
    num_assets_mk_rebal_filtro ={}
    for psi in psi_list:
        num_assets_mk_rebal_filtro[psi] = np.count_nonzero(weights_mk_filtro[psi]>cut)


    num_assets_mk_rebal = np.count_nonzero(weights_mk>cut)

    print(f"End of optimization {i+1} ----")

    next_period = df_assets.iloc[end:end + rebalancing_interval]
    if not next_period.empty:
        for psi in psi_list:
            weights_svc[psi] = calculate_svc_optimum_weights(window_data, gamma, psi)
            portfolio_returns_svc = next_period.dot(weights_svc[psi])
            cumulative_portfolio_returns_svc_dict[psi].extend(portfolio_returns_svc)
            diversity_svc_dict[psi].append(num_assets_svc_rebal[psi])
            hhi_svc_dict[psi].append(hhi_svc[psi])
            weights_svc_dict[psi].append(weights_svc[psi])

        for psi in psi_list:
            weights_mk_filtro[psi] = calculate_svc_optimum_weights(window_data_filtro, gamma, psi)
            portfolio_returns_mk_filtro= next_period.dot(weights_mk_filtro[psi])
            cumulative_portfolio_returns_mk_dict_filtro[psi].extend(portfolio_returns_mk_filtro)
            diversity_mk_dict_filtro[psi].append(num_assets_mk_rebal_filtro[psi])
            hhi_mk_dict_filtro[psi].append(hhi_mk_filtro[psi])
            weights_mk_dict_filtro[psi].append(weights_mk_filtro[psi])

        portfolio_returns_mk = next_period.dot(weights_mk)
        cumulative_portfolio_returns_mk.extend(portfolio_returns_mk)
        diversity_mk.append(num_assets_mk_rebal)
        hhi_mk_list.append(hhi_mk)
        weights_mk_list.append(weights_mk)

        portfolio_returns_equal = next_period.dot(weights_equal)
        cumulative_portfolio_returns_equal.extend(portfolio_returns_equal)
        hhi_equal_list.append(hhi_equal)
        weights_equal_list.append(weights_equal)

        dates.extend(next_period.index)


diversity_equal = np.repeat(num_assets, num_rebal)

cumulative_portfolio_returns_svc_series = {psi: [] for psi in psi_list}
cumulative_returns_svc = {psi: [] for psi in psi_list}
for psi in psi_list:
    cumulative_portfolio_returns_svc_series[psi] = pd.Series(cumulative_portfolio_returns_svc_dict[psi], index=dates)
    cumulative_returns_svc[psi] = (1 + cumulative_portfolio_returns_svc_series[psi]).cumprod() - 1



cumulative_portfolio_returns_mk_series_filtro = {psi: [] for psi in psi_list}
cumulative_returns_mk_filtro= {psi: [] for psi in psi_list}
for psi in psi_list:
    cumulative_portfolio_returns_mk_series_filtro[psi] = pd.Series(cumulative_portfolio_returns_mk_dict_filtro[psi], index=dates)
    cumulative_returns_mk_filtro[psi] = (1 + cumulative_portfolio_returns_mk_series_filtro[psi]).cumprod() - 1



cumulative_portfolio_returns_equal_series = pd.Series(cumulative_portfolio_returns_equal, index=dates)
cumulative_return_equal = (1 + cumulative_portfolio_returns_equal_series).cumprod() - 1

cumulative_portfolio_returns_mk_series = pd.Series(cumulative_portfolio_returns_mk, index=dates)
cumulative_return_mk = (1 + cumulative_portfolio_returns_mk_series).cumprod() - 1

cumulative_return_bench= (1 + df_bench.iloc[window_size:]).cumprod() - 1


######################

# Volatilidade
volatility_svc_1 = np.std(cumulative_portfolio_returns_svc_series[0.2]) 
volatility_svc_2 = np.std(cumulative_portfolio_returns_svc_series[0.5]) 
volatility_svc_3 = np.std(cumulative_portfolio_returns_svc_series[0.8]) 
volatility_mk = np.std(cumulative_portfolio_returns_mk_series)
volatility_equal = np.std(cumulative_portfolio_returns_equal_series)
volatility_bench = np.std(cumulative_return_bench)
volatility_mk_1 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.2]) 
volatility_mk_2 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.5]) 
volatility_mk_3 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.8]) 


# Drawdown
drawdown_svc_1 = calculate_drawdown(cumulative_returns_svc[0.2])
drawdown_svc_2 = calculate_drawdown(cumulative_returns_svc[0.5])
drawdown_svc_3 = calculate_drawdown(cumulative_returns_svc[0.8])
drawdown_mk = calculate_drawdown(cumulative_return_mk)
drawdown_equal = calculate_drawdown(cumulative_return_equal)
drawdown_bench = calculate_drawdown(cumulative_return_bench)
drawdown_mk_1 = calculate_drawdown(cumulative_returns_mk_filtro[0.2])
drawdown_mk_2 = calculate_drawdown(cumulative_returns_mk_filtro[0.5])
drawdown_mk_3 = calculate_drawdown(cumulative_returns_mk_filtro[0.8])


# # VaR
var_svc_1 = calculate_var(cumulative_portfolio_returns_svc_series[0.2], 0.95)
var_svc_2 = calculate_var(cumulative_portfolio_returns_svc_series[0.5], 0.95)
var_svc_3 = calculate_var(cumulative_portfolio_returns_svc_series[0.8], 0.95)
var_mk = calculate_var(cumulative_portfolio_returns_mk_series, 0.95)
var_equal = calculate_var(cumulative_portfolio_returns_equal_series, 0.95)
var_bench = calculate_var(df_bench.iloc[T:], 0.95)
var_mk_1 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.2], 0.95)
var_mk_2 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.5], 0.95)
var_mk_3 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.8], 0.95)

# # CVaR
cvar_svc_1 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.2], 0.95)
cvar_svc_2 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.5], 0.95)
cvar_svc_3 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.8], 0.95)
cvar_mk = calculate_cvar(cumulative_portfolio_returns_mk_series, 0.95)
cvar_equal = calculate_cvar(cumulative_portfolio_returns_equal_series, 0.95)
cvar_bench = calculate_cvar(df_bench.iloc[T:], 0.95)
cvar_mk_1 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.2], 0.95)
cvar_mk_2 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.5], 0.95)
cvar_mk_3 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.8], 0.95)


# # Sharpe
sharpe_ratio_svc_1 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.2], risk_free_rate)
sharpe_ratio_svc_2 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.5], risk_free_rate)
sharpe_ratio_svc_3 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.8], risk_free_rate)
sharpe_ratio_mk = calculate_sharpe_ratio(cumulative_return_mk, risk_free_rate)
sharpe_ratio_equal = calculate_sharpe_ratio(cumulative_return_equal, risk_free_rate)
sharpe_ratio_bench = calculate_sharpe_ratio(df_bench.iloc[T:], risk_free_rate)
sharpe_ratio_mk_1 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], risk_free_rate)
sharpe_ratio_mk_2 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], risk_free_rate)
sharpe_ratio_mk_3 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], risk_free_rate)

# # Sortino
sortino_ratio_svc_1 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.2], risk_free_rate)
sortino_ratio_svc_2 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.5], risk_free_rate)
sortino_ratio_svc_3 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.8], risk_free_rate)
sortino_ratio_mk = calculate_sortino_ratio(cumulative_return_mk, risk_free_rate)
sortino_ratio_equal = calculate_sortino_ratio(cumulative_return_equal, risk_free_rate)
sortino_ratio_bench= calculate_sortino_ratio(df_bench.iloc[T:], risk_free_rate)
sortino_ratio_mk_1 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], risk_free_rate)
sortino_ratio_mk_2 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], risk_free_rate)
sortino_ratio_mk_3 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], risk_free_rate)

# # Omega
omega_ratio_svc_1 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.2], threshold)
omega_ratio_svc_2 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.5], threshold)
omega_ratio_svc_3 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.8], threshold)
omega_ratio_mk = calculate_omega_ratio(cumulative_return_mk,  threshold)
omega_ratio_equal = calculate_omega_ratio(cumulative_return_equal,  threshold)
omega_ratio_bench = calculate_omega_ratio(df_bench.iloc[T:],  threshold)
omega_ratio_mk_1 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], threshold)
omega_ratio_mk_2 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], threshold)
omega_ratio_mk_3 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], threshold)

return_mean_svc_1 = np.mean(cumulative_portfolio_returns_svc_series[0.2])
return_mean_svc_2 = np.mean(cumulative_portfolio_returns_svc_series[0.5])
return_mean_svc_3 = np.mean(cumulative_portfolio_returns_svc_series[0.8])
return_mean_equal = np.mean(cumulative_portfolio_returns_equal_series)
return_mean_mk = np.mean(cumulative_portfolio_returns_mk_series)
return_mean_bench = np.mean(df_bench.iloc[window_size:])
return_mean_mk_1 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.2])
return_mean_mk_2 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.5])
return_mean_mk_3 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.8])

measures = {
    "Volatility": [volatility_mk, volatility_mk_1, volatility_mk_2, volatility_mk_3],
    "Max Drawdown": [drawdown_mk, drawdown_mk_1, drawdown_mk_2, drawdown_mk_3],
    "VaR (95%)": [var_mk, var_mk_1, var_mk_2, var_mk_3],
    "CVaR (95%)": [cvar_mk, var_mk_1, cvar_mk_2, cvar_mk_3],
    "Sharpe": [sharpe_ratio_mk, sharpe_ratio_mk_1, sharpe_ratio_mk_2, sharpe_ratio_mk_3],
    "Sortino": [sortino_ratio_mk, sortino_ratio_mk_1, sortino_ratio_mk_2, sortino_ratio_mk_3],
    "Omega": [omega_ratio_mk, omega_ratio_mk_1, omega_ratio_mk_2, omega_ratio_mk_3],
    "Return mean": [return_mean_mk, return_mean_mk_1, return_mean_mk_2, return_mean_mk_3]}    
index = ['MK', 'MK$_{0.2}$', 'MK$_{0.5}$', 'MK$_{0.8}$']
risk_measures_df_rebalanceado_semestral= pd.DataFrame(measures, index=index)
print(risk_measures_df_rebalanceado_semestral)
# Out:
# Number of rebalancings/optimizations:  4
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.6.0 24G419)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1 rows, 252 columns and 252 nonzeros
# Model fingerprint: 0x3e01b903
# Model has 31878 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   QObjective range [3e+02, 6e+02]
#   Bounds range     [2e-02, 2e-02]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 1 rows, 252 columns, 252 nonzeros
# Presolved model has 31878 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 251
#  AA' NZ     : 3.163e+04
#  Factor NZ  : 3.188e+04 (roughly 1 MB of memory)
#  Factor Ops : 5.366e+06 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# ...

# %%
gc.collect()

R = 252

test = df_assets.iloc[T:]
training = df_assets[:T]

window_size = T
rebalancing_interval = R
num_rebal = math.ceil((num_returns_total - window_size)/rebalancing_interval)

cumulative_portfolio_returns_svc_dict = {psi: [] for psi in psi_list}
cumulative_portfolio_returns_mk_dict_filtro = {psi: [] for psi in psi_list}
cumulative_portfolio_returns_equal=[]
cumulative_portfolio_returns_mk=[]
dates = []


diversity_svc_dict = {psi: [] for psi in psi_list}
diversity_mk_dict_filtro = {psi: [] for psi in psi_list}
diversity_mk = []


hhi_svc_dict = {psi: [] for psi in psi_list}
hhi_mk_dict_filtro = {psi: [] for psi in psi_list}
hhi_mk_list = []
hhi_equal_list = []


weights_svc_dict = {psi: [] for psi in psi_list}
weights_mk_dict_filtro = {psi: [] for psi in psi_list}
weights_mk_list = []
weights_equal_list = []


turnover_svc_dict = {psi: [] for psi in psi_list}
turnover_mk_dict_filtro = {psi: [] for psi in psi_list}
turnover_mk = []
turnover_equal = []


previous_weights_svc = {psi: None for psi in psi_list}
previous_weights_mk_filtro = {psi: None for psi in psi_list}
previous_weights_mk = None
previous_weights_equal = None

print("Number of rebalancings/optimizations: ", num_rebal)

for i, start in enumerate(range(0, num_returns_total- window_size, rebalancing_interval)):
    end = start + window_size
    window_data = df_assets.iloc[start:end]
    num_periodos, num_assets = window_data.shape

    weights_svc={}
    for psi in psi_list:
        weights_svc[psi] = calculate_svc_optimum_weights(window_data, gamma, psi)
    weights_mk_filtro={}
    for psi in psi_list:
        mean_vector = window_data.mean()
        distances = ((window_data - mean_vector) ** 2).sum(axis=1) ** 0.5
        filtro = distances.quantile(psi)  # escalar
        window_data_filtro = window_data[distances <= filtro]
        weights_mk_filtro[psi] = calculate_mk_optimum_weights(window_data_filtro, gamma)

    weights_mk = calculate_mk_optimum_weights(window_data, gamma)
    weights_equal = np.repeat(1/num_assets, num_assets)


    if previous_weights_mk is not None:
        for psi in psi_list:
            turnover_svc_dict[psi].append(np.sum(np.abs(weights_svc[psi] - previous_weights_svc[psi])))
        for psi in psi_list:
            turnover_mk_dict_filtro[psi].append(np.sum(np.abs(weights_mk_filtro[psi] - previous_weights_mk_filtro[psi])))

            turnover_mk.append(np.sum(np.abs(weights_mk - previous_weights_mk)))
            turnover_equal.append(np.sum(np.abs(weights_equal - previous_weights_equal)))


    previous_weights_svc ={}
    for psi in psi_list:
        previous_weights_svc[psi] = weights_svc[psi]
    previous_weights_mk_filtro ={}
    for psi in psi_list:
        previous_weights_mk_filtro[psi] = weights_mk_filtro[psi]

    previous_weights_mk = weights_mk
    previous_weights_equal = weights_equal

    hhi_svc={}
    for psi in psi_list:
        hhi_svc[psi] = np.sum(weights_svc[psi]**2)
    hhi_mk_filtro={}
    for psi in psi_list:
        hhi_mk_filtro[psi] = np.sum(weights_mk_filtro[psi]**2)
    hhi_mk = np.sum(weights_mk**2)
    hhi_equal = np.sum(weights_equal**2)

    num_assets_svc_rebal ={}
    for psi in psi_list:
        num_assets_svc_rebal[psi] = np.count_nonzero(weights_svc[psi]>cut)
    num_assets_mk_rebal_filtro ={}
    for psi in psi_list:
        num_assets_mk_rebal_filtro[psi] = np.count_nonzero(weights_mk_filtro[psi]>cut)


    num_assets_mk_rebal = np.count_nonzero(weights_mk>cut)

    print(f"End of optimization {i+1} ----")

    next_period = df_assets.iloc[end:end + rebalancing_interval]
    if not next_period.empty:
        for psi in psi_list:
            weights_svc[psi] = calculate_svc_optimum_weights(window_data, gamma, psi)
            portfolio_returns_svc = next_period.dot(weights_svc[psi])
            cumulative_portfolio_returns_svc_dict[psi].extend(portfolio_returns_svc)
            diversity_svc_dict[psi].append(num_assets_svc_rebal[psi])
            hhi_svc_dict[psi].append(hhi_svc[psi])
            weights_svc_dict[psi].append(weights_svc[psi])

        for psi in psi_list:
            weights_mk_filtro[psi] = calculate_svc_optimum_weights(window_data_filtro, gamma, psi)
            portfolio_returns_mk_filtro= next_period.dot(weights_mk_filtro[psi])
            cumulative_portfolio_returns_mk_dict_filtro[psi].extend(portfolio_returns_mk_filtro)
            diversity_mk_dict_filtro[psi].append(num_assets_mk_rebal_filtro[psi])
            hhi_mk_dict_filtro[psi].append(hhi_mk_filtro[psi])
            weights_mk_dict_filtro[psi].append(weights_mk_filtro[psi])

        portfolio_returns_mk = next_period.dot(weights_mk)
        cumulative_portfolio_returns_mk.extend(portfolio_returns_mk)
        diversity_mk.append(num_assets_mk_rebal)
        hhi_mk_list.append(hhi_mk)
        weights_mk_list.append(weights_mk)

        portfolio_returns_equal = next_period.dot(weights_equal)
        cumulative_portfolio_returns_equal.extend(portfolio_returns_equal)
        hhi_equal_list.append(hhi_equal)
        weights_equal_list.append(weights_equal)

        dates.extend(next_period.index)


diversity_equal = np.repeat(num_assets, num_rebal)

cumulative_portfolio_returns_svc_series = {psi: [] for psi in psi_list}
cumulative_returns_svc = {psi: [] for psi in psi_list}
for psi in psi_list:
    cumulative_portfolio_returns_svc_series[psi] = pd.Series(cumulative_portfolio_returns_svc_dict[psi], index=dates)
    cumulative_returns_svc[psi] = (1 + cumulative_portfolio_returns_svc_series[psi]).cumprod() - 1



cumulative_portfolio_returns_mk_series_filtro = {psi: [] for psi in psi_list}
cumulative_returns_mk_filtro= {psi: [] for psi in psi_list}
for psi in psi_list:
    cumulative_portfolio_returns_mk_series_filtro[psi] = pd.Series(cumulative_portfolio_returns_mk_dict_filtro[psi], index=dates)
    cumulative_returns_mk_filtro[psi] = (1 + cumulative_portfolio_returns_mk_series_filtro[psi]).cumprod() - 1



cumulative_portfolio_returns_equal_series = pd.Series(cumulative_portfolio_returns_equal, index=dates)
cumulative_return_equal = (1 + cumulative_portfolio_returns_equal_series).cumprod() - 1

cumulative_portfolio_returns_mk_series = pd.Series(cumulative_portfolio_returns_mk, index=dates)
cumulative_return_mk = (1 + cumulative_portfolio_returns_mk_series).cumprod() - 1

cumulative_return_bench= (1 + df_bench.iloc[window_size:]).cumprod() - 1


######################

# Volatilidade
volatility_svc_1 = np.std(cumulative_portfolio_returns_svc_series[0.2]) 
volatility_svc_2 = np.std(cumulative_portfolio_returns_svc_series[0.5]) 
volatility_svc_3 = np.std(cumulative_portfolio_returns_svc_series[0.8]) 
volatility_mk = np.std(cumulative_portfolio_returns_mk_series)
volatility_equal = np.std(cumulative_portfolio_returns_equal_series)
volatility_bench = np.std(cumulative_return_bench)
volatility_mk_1 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.2]) 
volatility_mk_2 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.5]) 
volatility_mk_3 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.8]) 


# Drawdown
drawdown_svc_1 = calculate_drawdown(cumulative_returns_svc[0.2])
drawdown_svc_2 = calculate_drawdown(cumulative_returns_svc[0.5])
drawdown_svc_3 = calculate_drawdown(cumulative_returns_svc[0.8])
drawdown_mk = calculate_drawdown(cumulative_return_mk)
drawdown_equal = calculate_drawdown(cumulative_return_equal)
drawdown_bench = calculate_drawdown(cumulative_return_bench)
drawdown_mk_1 = calculate_drawdown(cumulative_returns_mk_filtro[0.2])
drawdown_mk_2 = calculate_drawdown(cumulative_returns_mk_filtro[0.5])
drawdown_mk_3 = calculate_drawdown(cumulative_returns_mk_filtro[0.8])


# # VaR
var_svc_1 = calculate_var(cumulative_portfolio_returns_svc_series[0.2], 0.95)
var_svc_2 = calculate_var(cumulative_portfolio_returns_svc_series[0.5], 0.95)
var_svc_3 = calculate_var(cumulative_portfolio_returns_svc_series[0.8], 0.95)
var_mk = calculate_var(cumulative_portfolio_returns_mk_series, 0.95)
var_equal = calculate_var(cumulative_portfolio_returns_equal_series, 0.95)
var_bench = calculate_var(df_bench.iloc[T:], 0.95)
var_mk_1 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.2], 0.95)
var_mk_2 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.5], 0.95)
var_mk_3 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.8], 0.95)

# # CVaR
cvar_svc_1 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.2], 0.95)
cvar_svc_2 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.5], 0.95)
cvar_svc_3 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.8], 0.95)
cvar_mk = calculate_cvar(cumulative_portfolio_returns_mk_series, 0.95)
cvar_equal = calculate_cvar(cumulative_portfolio_returns_equal_series, 0.95)
cvar_bench = calculate_cvar(df_bench.iloc[T:], 0.95)
cvar_mk_1 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.2], 0.95)
cvar_mk_2 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.5], 0.95)
cvar_mk_3 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.8], 0.95)


# # Sharpe
sharpe_ratio_svc_1 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.2], risk_free_rate)
sharpe_ratio_svc_2 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.5], risk_free_rate)
sharpe_ratio_svc_3 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.8], risk_free_rate)
sharpe_ratio_mk = calculate_sharpe_ratio(cumulative_return_mk, risk_free_rate)
sharpe_ratio_equal = calculate_sharpe_ratio(cumulative_return_equal, risk_free_rate)
sharpe_ratio_bench = calculate_sharpe_ratio(df_bench.iloc[T:], risk_free_rate)
sharpe_ratio_mk_1 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], risk_free_rate)
sharpe_ratio_mk_2 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], risk_free_rate)
sharpe_ratio_mk_3 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], risk_free_rate)

# # Sortino
sortino_ratio_svc_1 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.2], risk_free_rate)
sortino_ratio_svc_2 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.5], risk_free_rate)
sortino_ratio_svc_3 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.8], risk_free_rate)
sortino_ratio_mk = calculate_sortino_ratio(cumulative_return_mk, risk_free_rate)
sortino_ratio_equal = calculate_sortino_ratio(cumulative_return_equal, risk_free_rate)
sortino_ratio_bench= calculate_sortino_ratio(df_bench.iloc[T:], risk_free_rate)
sortino_ratio_mk_1 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], risk_free_rate)
sortino_ratio_mk_2 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], risk_free_rate)
sortino_ratio_mk_3 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], risk_free_rate)

# # Omega
omega_ratio_svc_1 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.2], threshold)
omega_ratio_svc_2 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.5], threshold)
omega_ratio_svc_3 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.8], threshold)
omega_ratio_mk = calculate_omega_ratio(cumulative_return_mk,  threshold)
omega_ratio_equal = calculate_omega_ratio(cumulative_return_equal,  threshold)
omega_ratio_bench = calculate_omega_ratio(df_bench.iloc[T:],  threshold)
omega_ratio_mk_1 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], threshold)
omega_ratio_mk_2 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], threshold)
omega_ratio_mk_3 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], threshold)

return_mean_svc_1 = np.mean(cumulative_portfolio_returns_svc_series[0.2])
return_mean_svc_2 = np.mean(cumulative_portfolio_returns_svc_series[0.5])
return_mean_svc_3 = np.mean(cumulative_portfolio_returns_svc_series[0.8])
return_mean_equal = np.mean(cumulative_portfolio_returns_equal_series)
return_mean_mk = np.mean(cumulative_portfolio_returns_mk_series)
return_mean_bench = np.mean(df_bench.iloc[window_size:])
return_mean_mk_1 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.2])
return_mean_mk_2 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.5])
return_mean_mk_3 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.8])

measures = {
    "Volatility": [volatility_mk, volatility_mk_1, volatility_mk_2, volatility_mk_3],
    "Max Drawdown": [drawdown_mk, drawdown_mk_1, drawdown_mk_2, drawdown_mk_3],
    "VaR (95%)": [var_mk,  var_mk_1, var_mk_2, var_mk_3],
    "CVaR (95%)": [cvar_mk, var_mk_1, cvar_mk_2, cvar_mk_3],
    "Sharpe": [sharpe_ratio_mk, sharpe_ratio_mk_1, sharpe_ratio_mk_2, sharpe_ratio_mk_3],
    "Sortino": [sortino_ratio_mk, sortino_ratio_mk_1, sortino_ratio_mk_2, sortino_ratio_mk_3],
    "Omega": [omega_ratio_mk, omega_ratio_mk_1, omega_ratio_mk_2, omega_ratio_mk_3],
    "Return mean": [return_mean_mk, return_mean_mk_1, return_mean_mk_2, return_mean_mk_3]}    
index = ['MK', 'MK$_{0.2}$', 'MK$_{0.5}$', 'MK$_{0.8}$']
risk_measures_df_rebalanceado_anual= pd.DataFrame(measures, index=index)
print(risk_measures_df_rebalanceado_anual)
# Out:
# Number of rebalancings/optimizations:  2
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.6.0 24G419)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1 rows, 252 columns and 252 nonzeros
# Model fingerprint: 0x3e01b903
# Model has 31878 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   QObjective range [3e+02, 6e+02]
#   Bounds range     [2e-02, 2e-02]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 1 rows, 252 columns, 252 nonzeros
# Presolved model has 31878 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 251
#  AA' NZ     : 3.163e+04
#  Factor NZ  : 3.188e+04 (roughly 1 MB of memory)
#  Factor Ops : 5.366e+06 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# ...

# %%
gc.collect()

R = 252*2

test = df_assets.iloc[T:]
training = df_assets[:T]

window_size = T
rebalancing_interval = R
num_rebal = math.ceil((num_returns_total - window_size)/rebalancing_interval)

cumulative_portfolio_returns_svc_dict = {psi: [] for psi in psi_list}
cumulative_portfolio_returns_mk_dict_filtro = {psi: [] for psi in psi_list}
cumulative_portfolio_returns_equal=[]
cumulative_portfolio_returns_mk=[]
dates = []


diversity_svc_dict = {psi: [] for psi in psi_list}
diversity_mk_dict_filtro = {psi: [] for psi in psi_list}
diversity_mk = []


hhi_svc_dict = {psi: [] for psi in psi_list}
hhi_mk_dict_filtro = {psi: [] for psi in psi_list}
hhi_mk_list = []
hhi_equal_list = []


weights_svc_dict = {psi: [] for psi in psi_list}
weights_mk_dict_filtro = {psi: [] for psi in psi_list}
weights_mk_list = []
weights_equal_list = []


turnover_svc_dict = {psi: [] for psi in psi_list}
turnover_mk_dict_filtro = {psi: [] for psi in psi_list}
turnover_mk = []
turnover_equal = []


previous_weights_svc = {psi: None for psi in psi_list}
previous_weights_mk_filtro = {psi: None for psi in psi_list}
previous_weights_mk = None
previous_weights_equal = None

print("Number of rebalancings/optimizations: ", num_rebal)

for i, start in enumerate(range(0, num_returns_total- window_size, rebalancing_interval)):
    end = start + window_size
    window_data = df_assets.iloc[start:end]
    num_periodos, num_assets = window_data.shape

    weights_svc={}
    for psi in psi_list:
        weights_svc[psi] = calculate_svc_optimum_weights(window_data, gamma, psi)
    weights_mk_filtro={}
    for psi in psi_list:
        mean_vector = window_data.mean()
        distances = ((window_data - mean_vector) ** 2).sum(axis=1) ** 0.5
        filtro = distances.quantile(psi)  # escalar
        window_data_filtro = window_data[distances <= filtro]
        weights_mk_filtro[psi] = calculate_mk_optimum_weights(window_data_filtro, gamma)

    weights_mk = calculate_mk_optimum_weights(window_data, gamma)
    weights_equal = np.repeat(1/num_assets, num_assets)


    if previous_weights_mk is not None:
        for psi in psi_list:
            turnover_svc_dict[psi].append(np.sum(np.abs(weights_svc[psi] - previous_weights_svc[psi])))
        for psi in psi_list:
            turnover_mk_dict_filtro[psi].append(np.sum(np.abs(weights_mk_filtro[psi] - previous_weights_mk_filtro[psi])))

            turnover_mk.append(np.sum(np.abs(weights_mk - previous_weights_mk)))
            turnover_equal.append(np.sum(np.abs(weights_equal - previous_weights_equal)))


    previous_weights_svc ={}
    for psi in psi_list:
        previous_weights_svc[psi] = weights_svc[psi]
    previous_weights_mk_filtro ={}
    for psi in psi_list:
        previous_weights_mk_filtro[psi] = weights_mk_filtro[psi]

    previous_weights_mk = weights_mk
    previous_weights_equal = weights_equal

    hhi_svc={}
    for psi in psi_list:
        hhi_svc[psi] = np.sum(weights_svc[psi]**2)
    hhi_mk_filtro={}
    for psi in psi_list:
        hhi_mk_filtro[psi] = np.sum(weights_mk_filtro[psi]**2)
    hhi_mk = np.sum(weights_mk**2)
    hhi_equal = np.sum(weights_equal**2)

    num_assets_svc_rebal ={}
    for psi in psi_list:
        num_assets_svc_rebal[psi] = np.count_nonzero(weights_svc[psi]>cut)
    num_assets_mk_rebal_filtro ={}
    for psi in psi_list:
        num_assets_mk_rebal_filtro[psi] = np.count_nonzero(weights_mk_filtro[psi]>cut)


    num_assets_mk_rebal = np.count_nonzero(weights_mk>cut)

    print(f"End of optimization {i+1} ----")

    next_period = df_assets.iloc[end:end + rebalancing_interval]
    if not next_period.empty:
        for psi in psi_list:
            weights_svc[psi] = calculate_svc_optimum_weights(window_data, gamma, psi)
            portfolio_returns_svc = next_period.dot(weights_svc[psi])
            cumulative_portfolio_returns_svc_dict[psi].extend(portfolio_returns_svc)
            diversity_svc_dict[psi].append(num_assets_svc_rebal[psi])
            hhi_svc_dict[psi].append(hhi_svc[psi])
            weights_svc_dict[psi].append(weights_svc[psi])

        for psi in psi_list:
            weights_mk_filtro[psi] = calculate_svc_optimum_weights(window_data_filtro, gamma, psi)
            portfolio_returns_mk_filtro= next_period.dot(weights_mk_filtro[psi])
            cumulative_portfolio_returns_mk_dict_filtro[psi].extend(portfolio_returns_mk_filtro)
            diversity_mk_dict_filtro[psi].append(num_assets_mk_rebal_filtro[psi])
            hhi_mk_dict_filtro[psi].append(hhi_mk_filtro[psi])
            weights_mk_dict_filtro[psi].append(weights_mk_filtro[psi])

        portfolio_returns_mk = next_period.dot(weights_mk)
        cumulative_portfolio_returns_mk.extend(portfolio_returns_mk)
        diversity_mk.append(num_assets_mk_rebal)
        hhi_mk_list.append(hhi_mk)
        weights_mk_list.append(weights_mk)

        portfolio_returns_equal = next_period.dot(weights_equal)
        cumulative_portfolio_returns_equal.extend(portfolio_returns_equal)
        hhi_equal_list.append(hhi_equal)
        weights_equal_list.append(weights_equal)

        dates.extend(next_period.index)


diversity_equal = np.repeat(num_assets, num_rebal)

cumulative_portfolio_returns_svc_series = {psi: [] for psi in psi_list}
cumulative_returns_svc = {psi: [] for psi in psi_list}
for psi in psi_list:
    cumulative_portfolio_returns_svc_series[psi] = pd.Series(cumulative_portfolio_returns_svc_dict[psi], index=dates)
    cumulative_returns_svc[psi] = (1 + cumulative_portfolio_returns_svc_series[psi]).cumprod() - 1



cumulative_portfolio_returns_mk_series_filtro = {psi: [] for psi in psi_list}
cumulative_returns_mk_filtro= {psi: [] for psi in psi_list}
for psi in psi_list:
    cumulative_portfolio_returns_mk_series_filtro[psi] = pd.Series(cumulative_portfolio_returns_mk_dict_filtro[psi], index=dates)
    cumulative_returns_mk_filtro[psi] = (1 + cumulative_portfolio_returns_mk_series_filtro[psi]).cumprod() - 1



cumulative_portfolio_returns_equal_series = pd.Series(cumulative_portfolio_returns_equal, index=dates)
cumulative_return_equal = (1 + cumulative_portfolio_returns_equal_series).cumprod() - 1

cumulative_portfolio_returns_mk_series = pd.Series(cumulative_portfolio_returns_mk, index=dates)
cumulative_return_mk = (1 + cumulative_portfolio_returns_mk_series).cumprod() - 1

cumulative_return_bench= (1 + df_bench.iloc[window_size:]).cumprod() - 1


######################

# Volatilidade
volatility_svc_1 = np.std(cumulative_portfolio_returns_svc_series[0.2]) 
volatility_svc_2 = np.std(cumulative_portfolio_returns_svc_series[0.5]) 
volatility_svc_3 = np.std(cumulative_portfolio_returns_svc_series[0.8]) 
volatility_mk = np.std(cumulative_portfolio_returns_mk_series)
volatility_equal = np.std(cumulative_portfolio_returns_equal_series)
volatility_bench = np.std(cumulative_return_bench)
volatility_mk_1 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.2]) 
volatility_mk_2 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.5]) 
volatility_mk_3 = np.std(cumulative_portfolio_returns_mk_series_filtro[0.8]) 


# Drawdown
drawdown_svc_1 = calculate_drawdown(cumulative_returns_svc[0.2])
drawdown_svc_2 = calculate_drawdown(cumulative_returns_svc[0.5])
drawdown_svc_3 = calculate_drawdown(cumulative_returns_svc[0.8])
drawdown_mk = calculate_drawdown(cumulative_return_mk)
drawdown_equal = calculate_drawdown(cumulative_return_equal)
drawdown_bench = calculate_drawdown(cumulative_return_bench)
drawdown_mk_1 = calculate_drawdown(cumulative_returns_mk_filtro[0.2])
drawdown_mk_2 = calculate_drawdown(cumulative_returns_mk_filtro[0.5])
drawdown_mk_3 = calculate_drawdown(cumulative_returns_mk_filtro[0.8])


# # VaR
var_svc_1 = calculate_var(cumulative_portfolio_returns_svc_series[0.2], 0.95)
var_svc_2 = calculate_var(cumulative_portfolio_returns_svc_series[0.5], 0.95)
var_svc_3 = calculate_var(cumulative_portfolio_returns_svc_series[0.8], 0.95)
var_mk = calculate_var(cumulative_portfolio_returns_mk_series, 0.95)
var_equal = calculate_var(cumulative_portfolio_returns_equal_series, 0.95)
var_bench = calculate_var(df_bench.iloc[T:], 0.95)
var_mk_1 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.2], 0.95)
var_mk_2 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.5], 0.95)
var_mk_3 = calculate_var(cumulative_portfolio_returns_mk_series_filtro[0.8], 0.95)

# # CVaR
cvar_svc_1 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.2], 0.95)
cvar_svc_2 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.5], 0.95)
cvar_svc_3 = calculate_cvar(cumulative_portfolio_returns_svc_series[0.8], 0.95)
cvar_mk = calculate_cvar(cumulative_portfolio_returns_mk_series, 0.95)
cvar_equal = calculate_cvar(cumulative_portfolio_returns_equal_series, 0.95)
cvar_bench = calculate_cvar(df_bench.iloc[T:], 0.95)
cvar_mk_1 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.2], 0.95)
cvar_mk_2 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.5], 0.95)
cvar_mk_3 = calculate_cvar(cumulative_portfolio_returns_mk_series_filtro[0.8], 0.95)


# # Sharpe
sharpe_ratio_svc_1 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.2], risk_free_rate)
sharpe_ratio_svc_2 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.5], risk_free_rate)
sharpe_ratio_svc_3 = calculate_sharpe_ratio(cumulative_portfolio_returns_svc_dict[0.8], risk_free_rate)
sharpe_ratio_mk = calculate_sharpe_ratio(cumulative_return_mk, risk_free_rate)
sharpe_ratio_equal = calculate_sharpe_ratio(cumulative_return_equal, risk_free_rate)
sharpe_ratio_bench = calculate_sharpe_ratio(df_bench.iloc[T:], risk_free_rate)
sharpe_ratio_mk_1 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], risk_free_rate)
sharpe_ratio_mk_2 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], risk_free_rate)
sharpe_ratio_mk_3 = calculate_sharpe_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], risk_free_rate)

# # Sortino
sortino_ratio_svc_1 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.2], risk_free_rate)
sortino_ratio_svc_2 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.5], risk_free_rate)
sortino_ratio_svc_3 = calculate_sortino_ratio(cumulative_portfolio_returns_svc_dict[0.8], risk_free_rate)
sortino_ratio_mk = calculate_sortino_ratio(cumulative_return_mk, risk_free_rate)
sortino_ratio_equal = calculate_sortino_ratio(cumulative_return_equal, risk_free_rate)
sortino_ratio_bench= calculate_sortino_ratio(df_bench.iloc[T:], risk_free_rate)
sortino_ratio_mk_1 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], risk_free_rate)
sortino_ratio_mk_2 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], risk_free_rate)
sortino_ratio_mk_3 = calculate_sortino_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], risk_free_rate)

# # Omega
omega_ratio_svc_1 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.2], threshold)
omega_ratio_svc_2 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.5], threshold)
omega_ratio_svc_3 = calculate_omega_ratio(cumulative_portfolio_returns_svc_dict[0.8], threshold)
omega_ratio_mk = calculate_omega_ratio(cumulative_return_mk,  threshold)
omega_ratio_equal = calculate_omega_ratio(cumulative_return_equal,  threshold)
omega_ratio_bench = calculate_omega_ratio(df_bench.iloc[T:],  threshold)
omega_ratio_mk_1 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.2], threshold)
omega_ratio_mk_2 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.5], threshold)
omega_ratio_mk_3 = calculate_omega_ratio(cumulative_portfolio_returns_mk_dict_filtro[0.8], threshold)

return_mean_svc_1 = np.mean(cumulative_portfolio_returns_svc_series[0.2])
return_mean_svc_2 = np.mean(cumulative_portfolio_returns_svc_series[0.5])
return_mean_svc_3 = np.mean(cumulative_portfolio_returns_svc_series[0.8])
return_mean_equal = np.mean(cumulative_portfolio_returns_equal_series)
return_mean_mk = np.mean(cumulative_portfolio_returns_mk_series)
return_mean_bench = np.mean(df_bench.iloc[window_size:])
return_mean_mk_1 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.2])
return_mean_mk_2 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.5])
return_mean_mk_3 = np.mean(cumulative_portfolio_returns_mk_series_filtro[0.8])

measures = {
    "Volatility": [volatility_mk, volatility_mk_1, volatility_mk_2, volatility_mk_3],
    "Max Drawdown": [drawdown_mk, drawdown_mk_1, drawdown_mk_2, drawdown_mk_3],
    "VaR (95%)": [var_mk, var_mk_1, var_mk_2, var_mk_3],
    "CVaR (95%)": [cvar_mk, var_mk_1, cvar_mk_2, cvar_mk_3],
    "Sharpe": [sharpe_ratio_mk, sharpe_ratio_mk_1, sharpe_ratio_mk_2, sharpe_ratio_mk_3],
    "Sortino": [sortino_ratio_mk, sortino_ratio_mk_1, sortino_ratio_mk_2, sortino_ratio_mk_3],
    "Omega": [omega_ratio_mk, omega_ratio_mk_1, omega_ratio_mk_2, omega_ratio_mk_3],
    "Return mean": [return_mean_mk, return_mean_mk_1, return_mean_mk_2, return_mean_mk_3]}    
index = ['MK', 'MK$_{0.2}$', 'MK$_{0.5}$', 'MK$_{0.8}$']
risk_measures_df_rebalanceado_buyandhold= pd.DataFrame(measures, index=index)
print(risk_measures_df_rebalanceado_buyandhold)
# Out:
# Number of rebalancings/optimizations:  1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 24.6.0 24G419)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1 rows, 252 columns and 252 nonzeros
# Model fingerprint: 0x3e01b903
# Model has 31878 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+02, 2e+02]
#   QObjective range [3e+02, 6e+02]
#   Bounds range     [2e-02, 2e-02]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 1 rows, 252 columns, 252 nonzeros
# Presolved model has 31878 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 251
#  AA' NZ     : 3.163e+04
#  Factor NZ  : 3.188e+04 (roughly 1 MB of memory)
#  Factor Ops : 5.366e+06 (less than 1 second per iteration)
#  Threads    : 8
#
#                   Objective                Residual
# ...

# %%
dfs = {
    "Buy&Hold": risk_measures_df_rebalanceado_buyandhold,
    "Trimestral": risk_measures_df_rebalanceado_trimestral,
    "Semestral": risk_measures_df_rebalanceado_semestral,
    "Anual": risk_measures_df_rebalanceado_anual
}

def build_table(measure_name, dfs):
    tabela = pd.DataFrame({
        periodo: dfs[periodo][measure_name]
        for periodo in dfs
    })
    return tabela.round(3)

tabelas = {}
for measure in dfs["Buy&Hold"].columns:
    tabelas[measure] = build_table(measure, dfs)

sharpe_df = tabelas["Sharpe"]
vol_df = tabelas["Volatility"]
ret_df = tabelas["Return mean"]

print(sharpe_df)
print(vol_df)
print(ret_df)

sharpe_df.to_csv("sharpe.csv", float_format="%.3f")
vol_df.to_csv("volatility.csv", float_format="%.3f")
ret_df.to_csv("return_mean.csv", float_format="%.3f")

print(sharpe_df.to_latex(float_format="%.3f"))
print(vol_df.to_latex(float_format="%.3f"))
print(ret_df.to_latex(float_format="%.3f"))
# Out:
#             Buy&Hold  Trimestral  Semestral  Anual
# MK            -2.969      -1.271     -2.978 -2.973
# MK$_{0.2}$     0.061       0.045      0.049  0.030
# MK$_{0.5}$    -0.032      -0.003     -0.034 -0.041
# MK$_{0.8}$     0.076       0.050      0.058  0.046
#             Buy&Hold  Trimestral  Semestral  Anual
# MK             0.054       0.017      0.055  0.056
# MK$_{0.2}$     0.023       0.018      0.018  0.021
# MK$_{0.5}$     0.096       0.027      0.095  0.095
# MK$_{0.8}$     0.009       0.014      0.012  0.009
#             Buy&Hold  Trimestral  Semestral  Anual
# MK            -0.001      -0.000     -0.002 -0.002
# MK$_{0.2}$     0.001       0.001      0.001  0.001
# MK$_{0.5}$    -0.003      -0.000     -0.003 -0.004
# MK$_{0.8}$     0.001       0.001      0.001  0.000
# \begin{tabular}{lrrrr}
# \toprule
#  & Buy&Hold & Trimestral & Semestral & Anual \\
# \midrule
# MK & -2.969 & -1.271 & -2.978 & -2.973 \\
# MK$_{0.2}$ & 0.061 & 0.045 & 0.049 & 0.030 \\
# ...

# %%
fig, axes = plt.subplots(1,3, figsize=(14,4))

data = [ret_df, vol_df, sharpe_df]
titles = ["Retorno Médio", "Volatilidade", "Índice Sharpe"]
cmaps = ["Greens", "Oranges", "Blues"]

formatter = FuncFormatter(lambda x, _: f"{x:.3f}".rstrip('0').rstrip('.'))

for ax, d, t, c in zip(axes, data, titles, cmaps):
    hm = sns.heatmap(d, annot=True, cmap=c, fmt=".3f",
                     annot_kws={"size":11},
                     cbar_kws={"shrink":0.8},
                     ax=ax)

    ax.set_title(t, fontsize=14, pad=12)
    ax.tick_params(labelsize=10, rotation = 0)

    cbar = hm.collections[0].colorbar
    cbar.ax.yaxis.set_major_formatter(formatter)

plt.tight_layout()
plt.savefig('heatmap_unico.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.show()
